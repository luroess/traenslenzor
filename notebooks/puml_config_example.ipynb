# %% [markdown]
# # ExperimentConfig → PlantUML workflow
#
# This notebook demonstrates how to export an `ExperimentConfig` to a `.puml` diagram and load it back.

# %%
from traenslenzor.doc_classifier.configs import ExperimentConfig

config = ExperimentConfig()
puml_path = config.export_puml("demo_experiment.puml")
print(f"PUML written to {puml_path}")

loaded = ExperimentConfig.from_puml_file(puml_path)
print("Reloaded stage:", loaded.stage)
